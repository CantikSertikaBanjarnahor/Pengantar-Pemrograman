# %%
import pandas as pd #baca data excel
from scipy.stats.mstats import gmean, hmean #untuk mengelola numerik
import matplotlib.pyplot as plt #untuk membuat grafik

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_traces') #menyimpan data excel dalam variabel my_dataset

a_mean = my_dataset.Zr.mean() #menghitung rata-rata aritmatika dari kolom Sr
g_mean = gmean(my_dataset['Sr']) #Menghitung rata-rata geometri dari Sr
h_mean = hmean(my_dataset['Sr']) #menghitung rata-rata harmonik dari data Sr

print ('-------') #mencetak garis pemisah di output
print ('arithmetic mean') #menampilkan judul
print ("{0:.1f} [ppm]".format(a_mean)) #untuk menampilkan nilai a_mean dengan 1 angka di belakang koma + satuan ppm
print ('-------') #garis untuk misahin akhir

print ('geometric mean') #menapilkan judul
print ("{0:.1f} [ppm]".format(g_mean)) #menampilkan nilai g_mean
print ('-------') #garis untuk misah

print ('harmonic mean') #menampilkan judul
print ("{0:.1f} [ppm]".format(h_mean)) #menampilkan nilai h_hmean
print ('-------') #garis pemisah akhir

fig, ax = plt.subplots() #fig untuk menggambar seluruh gambar grafik, ax untuk menggambar area grafik
ax.hist(my_dataset.Sr, bins='auto', density=True, edgecolor='k', label='Measurements Hist', alpha=0.8, color='pink') ##membuat histogram atau diagram batang distribusi data dari nilai Sr
ax.axvline(a_mean, color='purple', label='Arithmetic mean', linewidth=2) #mberi warna ungu pada area aritmetic mean
ax.axvline(g_mean, color='orange',  label='Geometric mean', linewidth=2) #memberi warna orens pada area geometric mean
ax.axvline(h_mean, color='green',  label='Harmonic mean', linewidth=2) #memberi warna hijau pada area harmonic mean
ax.set_xlabel('Sr [ppm]')#memberi nama pada sumbu x
ax.set_ylabel('Probability density')#meberi nama pada sumbu y
ax.legend()#untuk menampilkan legenda pada grafik
# Out:
# -------
# arithmetic mean
# 365.4 [ppm]
# -------
# geometric mean
# nan [ppm]
# -------
# harmonic mean
# nan [ppm]
# -------

# %%
import pandas as pd #baca data excel
import matplotlib.pyplot as plt #memanggil matplotlib untuk membuat grafik

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_traces') #menyimpan sebuah data file excel dalam variabel my_dataset

median = my_dataset.Er.median() #menyimpan nilai data tengah dari data Er

print ('-------') #menampilkan garis pemisah di output
print ('median') #menampilkan teks median sebagai judul
print("{0:.1f} [ppm]".format(median)) #menampilkan nilai median dengan format rapih
print ('-------') #menampilkan garis penutup output

fig, ax = plt.subplots() #membuat kanvas dan area grafik
ax.hist(my_dataset.Er, bins=20, density=True, edgecolor='k', label="Measurements Hist", alpha=0.8, color='green') 
# membuat histogram dari data Er
# bins=20 = membagi data jadi 20 kelas
# density=True = menampilkan dalam bentuk distribusi (bukan jumlah absolut)
# edgecolor='k' = warna garis tepi histogram hitam
# label = nama untuk legenda
# alpha=0.8 = transparansi (0 = transparan, 1 = solid)
ax.axvline(median, color='orange', label='Median', linewidth=2)
# membuat garis vertikal pada nilai median
# median = posisi garis di sumbu x
# color='red' → warna garis merah
# label='Median' → nama di legenda
# linewidth=2 → ketebalan garis
ax.set_xlabel('Er [ppm]')#memberi nama pada sumbu x
ax.set_ylabel('Probability density')#memberi nama pada sumbu y
ax.legend()#menampilkan legenda pada grafik

'''
Output:
-------
median
339.4 [ppm]
-------
'''
# Out:
# -------
# median
# 3.1 [ppm]
# -------
# '\nOutput:\n-------\nmedian\n339.4 [ppm]\n-------\n'

# %%
import pandas as pd #baca data excel
import numpy as np  #untuk numerik
import matplotlib.pyplot as plt ##untuk membuat grafik

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_traces') #menyimpan data excel ke dalam variabel

hist, bin_edges = np.histogram(my_dataset['Ba'], bins= 20, density=True) 
# np.histogram(...) = menghitung distribusi data tanpa menampilkan grafik
# my_dataset['Ba'] = mengambil data dari kolom Ba
# bins=20 = membagi data menjadi 20 kelas interval
# density=True = hasil histogram dalam bentuk probabilitas (bukan jumlah)
# hist = nilai tinggi tiap bin (frekuensi / densitas)
# bin_edges = batas-batas tiap bin (array panjangnya bins+1)
modal_value = (bin_edges[hist.argmax()] +  bin_edges[hist.argmax()+1])/2
# hist.argmax() = mencari indeks bin dengan nilai tertinggi (modus)
# bin_edges[hist.argmax()] = batas bawah bin modus
# bin_edges[hist.argmax()+1] = batas atas bin modus
# dijumlah lalu dibagi 2 = titik tengah bin (dianggap sebagai nilai modus)
print ('modal value: {0:.0f} [ppm]'.format(modal_value))
# print(...) = menampilkan hasil ke layar
# {0:.0f} = format angka tanpa desimal (dibulatkan)
# [ppm] = satuan (parts per million)
fig, ax = plt.subplots()
# plt.subplots() = membuat "kanvas" dan "area plot"
# fig (figure) = seluruh halaman / kanvas gambar
# ax (axes) = area tempat grafik digambar
ax.hist(my_dataset.Ba, bins=20, density=True, edgecolor='k', label="Measurements Hist", alpha=0.8, color='red') 
# ax.hist(...) = membuat histogram (diagram batang distribusi data)
# my_dataset.Br = mengambil data dari kolom "Ba" di dataframe
# bins=20 = jumlah pembagian batang (20 kelas interval)
# density=True = mengubah histogram jadi bentuk probabilitas (bukan jumlah data)
# edgecolor='k' = warna garis tepi batang (k = hitam)
# label="Measurements Hist" = label untuk legenda
# alpha=0.8 = transparansi (0 = transparan, 1 = solid)
ax.axvline(modal_value, color="orange", label="Modal value", linewidth=2)
# ax.axvline(...) = membuat garis vertikal pada grafik
# median = posisi garis di nilai median data
# color='orange' = warna garis
# label='Median' = label untuk legenda
# linewidth=2 = ketebalan garis
ax.set_xlabel('Ba [ppm]')#memberi nama pada sumbu x
ax.set_ylabel('Probability density')#memberi nama pada sumbu y
ax.legend()#untuk menampilkan legenda pada grafik

'''
Output: modal value: 277 [ppm]
'''
# Out:
# modal value: 254 [ppm]
# '\nOutput: modal value: 277 [ppm]\n'

# %%
import pandas as pd #baca data excel
import matplotlib.pyplot as plt #untuk membuat grafik

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_traces') #menyimpan data file excel kedalam variabel my_dataset

my_range = my_dataset['Dy'].max()- my_dataset['Dy'].min()
# menghitung rentang (range) data Dy
# .max() = mengambil nilai terbesar
# .min() = mengambil nilai terkecil
# hasilnya = selisih nilai maksimum dan minimum

print ('-------') #menampilkan garis pemisah di output
print ('Range') #menampilkan teks range sebagai judul
print("{0:.0f}".format(my_range)) 
# menampilkan nilai my_range ke layar
# "{0:.0f}" → format angka tanpa angka di belakang koma (dibulatkan ke bilangan bulat)
# my_range → nilai rentang data yang akan ditampilkan
print ('-------') #menampilkan garis penutup

fig, ax = plt.subplots() #fig untuk menampilkan kanvas grafik, ax untuk menampilkan area grafik
ax.hist(my_dataset.Zr, bins=20, density=True, edgecolor='k', label='Measurements Hist', color='navy') #menampilkan histogram dari data yang ada di dalam variabel my_dataset
ax.axvline(my_dataset['Dy'].max(), color='purple', label='Max value', linewidth=2) #memberi warna ungu pada bagian max value
ax.axvline(my_dataset['Dy'].min(), color='green', label='Min value', linewidth=2) #memberikan warna hijau pada bagian min value
ax.axvspan(my_dataset['Dy'].min(), my_dataset['Zr'].max(), alpha=0.1, color='orange', label='Range = ' + "{0:.0f}".format(my_range) + ' ppm')
# membuat area berwarna (shading) dari nilai minimum sampai maksimum data Dy
# digunakan untuk menunjukkan rentang (range) data pada grafik
# label menampilkan nilai range dalam bentuk bilangan bulat + satuan ppm
ax.set_xlabel('Dy [ppm]')  #memberi nama pada sumbu x
ax.set_ylabel('Probability density') #memberi nama pada sumbu y
ax.legend() #menampilkan legenda pada grafik
# Out:
# -------
# Range
# 15
# -------

# %%
import pandas as pd #baca data excel
import matplotlib.pyplot as plt #untuk membuat grafik

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_traces') #menyimpan data file excel ke variabel my_dataset

variance =  my_dataset['Ho'].var()
# menghitung variance (ragam) dari data Ho
# menunjukkan seberapa besar penyebaran data terhadap
stddev =  my_dataset['Ho'].std() 
# menghitung standar deviasi dari data Zr
# menunjukkan seberapa jauh data menyebar dari rata-rata (akar dari variance)

print ('-------') #tampilkan garis pemisah di output
print ('Variance') #menampilkan nama variance sebagai judul
print("{0:.0f} [square ppm]".format(variance)) #menampilkan nilai variance
print ('-------') #menampilkan garis pemisah 
print ('Standard Deviation') #membuat judul standard deviation
print("{0:.0f} [ppm]".format(stddev)) #menampilkan nilai stddev
print ('-------') #menampilkan garis pemisah

fig, ax = plt.subplots() #fig untuk menghasilkan kanvas, ax untuk menghasilkan area grafik
ax.hist(my_dataset.Ho, bins= 20, density = True, edgecolor='k', label='Measurements Hist', color='orange') #menampilkan histogram dari file dalam variabel my_dataset
ax.axvline(my_dataset['Ho'].mean()-stddev, color='purple', label=r'mean - 1$\sigma$', linewidth=2) #memberi warna pink pada mean -1
ax.axvline(my_dataset['Ho'].mean()+stddev, color='green', label=r'mean + 1$\sigma$', linewidth=2)#memberi warna pink pada mean -1
ax.axvspan(my_dataset['Ho'].mean()-stddev, my_dataset['Ho'].mean()+stddev, alpha=0.1, color='orange', label=r'mean $\pm$ 1$\sigma$')#memberi warna blue pada  mean -+ 1
ax.set_xlabel('Ho [ppm]')#memberi nama pada sumbuh x
ax.set_ylabel('Probability density')#memberi nama pada sumbu y
ax.legend()#menampilkan legenda pada grafik

'''
Output:
-------
Variance
14021 [square ppm]
-------
Standard Deviation
118 [ppm]
-------
'''
# Out:
# -------
# Variance
# 0 [square ppm]
# -------
# Standard Deviation
# 0 [ppm]
# -------
# '\nOutput:\n-------\nVariance\n14021 [square ppm]\n-------\nStandard Deviation\n118 [ppm]\n-------\n'

# %%
import pandas as pd #Pandas untuk membaca file excel
import numpy as np #numpy untuk mengelola data angka
import matplotlib.pyplot as plt #untuk membuat grafik

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_traces') #menyimpan data excel dalam variabel my_dataset

q1 = np.percentile(my_dataset.Sr, 46, method = 'midpoint') #menghitung kuartil 1 (46%) dari data Sr batas bawah IQR
q3 = np.percentile(my_dataset.Sr, 25, method = 'midpoint') #menghitung kuartil 3 (25%) dari data Zr batas atas IQR
  
iqr = q3 - q1 # Interquaritle range (IQR)  

print ('-------')#menampilkan garis pemisah di output
print ('Interquaritle range (IQR): {0:.0f} [ppm]'.format(iqr))#untuk menampilkan interquaritle range beserta nilai nya tanpa desimal
print ('-------')#menampilkan garis pemisah

fig, ax = plt.subplots()#fig untuk menampilkan kanvas, ax untuk menampilkan area grafik
ax.hist(my_dataset.Sr, bins='auto', density=True, edgecolor='k', label='Measurements Hist', color='black') #menampilkan histogram dari variabel my_dataset
ax.axvline(q1, color='purple', label='Q1', linewidth=2)#menapilkan warna pink pada Q1
ax.axvline(q3, color='green', label='Q3', linewidth=2)#menapilkan warna black pada Q3
ax.axvspan(q1, q3, alpha=0.1, color='orange', label='Interquaritle range (IQR)')#untuk menandai area pada grafik antara nilai Q1 dan Q3 yaitu rentang IQR
ax.set_xlabel('Sr [ppm]')#memberi nama pada sumbu x
ax.set_ylabel('Probability density')#memberi nama pada sumbu y
ax.legend()#menampilkan legenda pada grafik

'''
Output:
-------
Interquaritle range (IQR): 164 [ppm]
-------
'''
# Out:
# -------
# Interquaritle range (IQR): nan [ppm]
# -------
# '\nOutput:\n-------\nInterquaritle range (IQR): 164 [ppm]\n-------\n'

# %%
import pandas as pd #membaca file excel
import numpy as np #mengelola data angka 
import matplotlib.pyplot as plt #untuk membaca grafik

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_traces')#menyimpan file excel ke variabel  my_dataset

a_mean = my_dataset.Zr.mean()#menghitung nilai rata-rata dari data Zr

median = my_dataset.Zr.median()#menghitung nilai tengah dari Zr

hist, bin_edges = np.histogram(my_dataset['Zr'], bins=20, density=True)#Membuat histogram → hist = jumlah/frekuensi tiap bin, bin_edges = batas tiap bin (20 kelas)
modal_value = (bin_edges[hist.argmax()] +  bin_edges[hist.argmax()+1])/2#Menghitung nilai modus → ambil bin dengan frekuensi tertinggi, lalu cari titik tengah bin tersebut

fig, ax = plt.subplots()#fig untuk menampilakn kanvas, ax untuk menampilkan area grafik
ax.hist(my_dataset.Zr, bins=20, density=True, edgecolor='k', label="Measurements Hist", color='purple') #menggambar histogram dari data di variabel my_dataset
ax.axvline(modal_value, color='orange', label='Modal Value', linewidth=2)#menggambar area modal value dengan warna orange 
ax.axvline(median, color='purple',  label='Median Value', linewidth=2) #menggambar area Median Value dengan warna purple
ax.axvline(a_mean, color='green',  label='Arithmetic mean', linewidth=2)#menggambar area Arithmetic mean dengan warna green
ax.set_xlabel('Sr [ppm]')#memberi nama pada sumbu x
ax.set_ylabel('Probability density')#memberi nama pada sumbu y
ax.legend()#menampilkan legenda pada grafik

# %%
import numpy as np #untuk perhitungan matematika
from scipy.stats import skew #untuk menghitung nilai skewness

a_mean = my_dataset.Zr.mean()#menghitung nilai rata-rata dari kolom Zr
median = my_dataset.Zr.median()#menghitung nilai tengah dari kolom Zr
hist, bin_edges = np.histogram(my_dataset['Zr'], bins=20, density=True)
# membuat histogram dalam bentuk data:
# hist = tinggi/frekuensi tiap bin
# bin_edges = batas-batas tiap bin
modal_value = (bin_edges[hist.argmax()] + bin_edges[hist.argmax()+1])/2
# mencari nilai modus (nilai paling sering muncul):
# hist.argmax() = indeks bin dengan frekuensi tertinggi
# lalu diambil titik tengah dari bin tersebut
standard_deviation = my_dataset['Zr'].std()#menghitung standar deviasi (sebaran data dari rata-rata)


a1 = (a_mean - modal_value) / standard_deviation # Pearson skewness pertama # membandingkan mean dengan modus
a2 = 3 * (a_mean - median) / standard_deviation# Pearson skewness kedua # membandingkan mean dengan median
g1 = skew(my_dataset['Zr'])

print ('-------')#membuat garis pemisah
print ("Pearson's first coefficient of skewness: {:.2f}".format(a1))#menampilkan nilai skewness Pearson pertama (2 angka di belakang koma)
print ("Pearson's 2nd moment of skewness: {:.2f}".format(a2))#menampilkan nilai skewness Pearson kedua
print ("Fisher-Pearson's coefficient of skewness: {:.2f}".format(g1))#menampilkan skewness versi scipy (Fisher-Pearson)
print ('-------')#garis penutup

'''
Output:
-------
Pearson's first coefficient of skewness: 0.74
Pearson's 2nd moment of skewness: 0.66
Fisher-Pearson's coefficient of skewness: 1.26
-------
'''
# Out:
# -------
# Pearson's first coefficient of skewness: 0.74
# Pearson's 2nd moment of skewness: 0.66
# Fisher-Pearson's coefficient of skewness: 1.26
# -------
# "\nOutput:\n-------\nPearson's first coefficient of skewness: 0.74\nPearson's 2nd moment of skewness: 0.66\nFisher-Pearson's coefficient of skewness: 1.26\n-------\n"

# %%
import pandas as pd #untuk membaca file excel

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_traces')#menyimpan data file excel ke dalam variay_dataset

statistics = my_dataset[['Ba','Sr','Zr','La']].describe()
# memilih kolom Ba, Sr, Zr, La lalu menghitung statistik deskriptif:
# count (jumlah data), mean (rata-rata), std (standar deviasi),
# min, 25%, 50% (median), 75%, dan max

print(statistics)#menampilkan hasil statistik deskriptif tersebut ke layar

'''
Output:
                Ba           Sr          Zr          La
count   370.000000   369.000000  370.000000  370.000000
mean    789.733259   516.422115  365.377397   74.861088
std     523.974960   241.922439  118.409962   18.256772
min       0.000000     9.541958  185.416567   45.323289
25%     297.402777   319.667551  274.660242   61.745228
50%     768.562055   490.111131  339.412064   71.642167
75%    1278.422645   728.726116  438.847368   83.670805
max    2028.221963  1056.132069  920.174406  169.550008
'''
# Out:
#                 Ba           Sr          Zr          La
# count   370.000000   369.000000  370.000000  370.000000
# mean    789.733259   516.422115  365.377397   74.861088
# std     523.974960   241.922439  118.409962   18.256772
# min       0.000000     9.541958  185.416567   45.323289
# 25%     297.402777   319.667551  274.660242   61.745228
# 50%     768.562055   490.111131  339.412064   71.642167
# 75%    1278.422645   728.726116  438.847368   83.670805
# max    2028.221963  1056.132069  920.174406  169.550008
# ...

# %%
import pandas as pd  #untuk baca file excel
import matplotlib.pyplot as plt#untuk membuat grafik

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_traces')#untuk menyimpan data file ke variabel my_dataset

fig, ax = plt.subplots()#fig untuk menampilkan kanvas, ax untuk menggambar area grafik
my_flierprops = dict(markerfacecolor="#26c042", markeredgecolor='#24305e', marker='o') 
my_medianprops = dict(color='#f76c6c', linewidth = 2)
my_boxprops = dict(facecolor='#a8d0e6', edgecolor='#24305e')
ax.boxplot(my_dataset.Zr, patch_artist = True, notch=True, flierprops=my_flierprops, medianprops=my_medianprops, boxprops=my_boxprops) 
ax.set_ylabel('Sr [ppm]') #memberi nama pada sumbu y
ax.set_xticks([1])
ax.set_xticklabels(['all Epochs'])#untuk memberi nama pada sumbu x
plt.show()#untuk menampilkan grafik

# %%
import pandas as pd #untuk membaca file excel
import matplotlib.pyplot as plt#untuk membuat grafik
import seaborn as sns#mengimpor library Seaborn untuk membuat visualisasi data (grafik) yang lebih menarik dan muda

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_traces')#menyimpan data file excel kedalam variabel my_dataset

fig, ax = plt.subplots()#menyimpan data file excel kedalam variabel my_dataset

ax = sns.boxplot(x="Epoch", y="Zr", data=my_dataset,  palette="Set3")
# membuat grafik boxplot:
# x="Epoch" → data pada sumbu X 
# y="Zr" → data pada sumbu Y 
# data=my_dataset → sumber data dari dataframe my_dataset
# palette="Set3" → mengatur warna boxplot 
# ax → menyimpan objek grafik agar bisa dimodifikasi lagi
# Out:
# /var/folders/yq/77jh3qf514n07q8dq793r06h0000gp/T/ipykernel_1015/3069188260.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x="Epoch", y="Zr", data=my_dataset,  palette="Set3")
